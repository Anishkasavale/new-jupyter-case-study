# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"G:\codes\archive.zip")
df
# Out:
#      Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 0          1052  2023-02-03       Bob  North       5053.97             18
# 1          1093  2023-04-21       Bob   West       4384.02             17
# 2          1015  2023-09-21     David  South       4631.23             30
# 3          1072  2023-08-24       Bob  South       2167.94             39
# 4          1061  2023-03-24   Charlie   East       3750.20             13
# ..          ...         ...       ...    ...           ...            ...
# 995        1010  2023-04-15   Charlie  North       4733.88              4
# 996        1067  2023-09-07       Bob  North       4716.36             37
# 997        1018  2023-04-27     David  South       7629.70             17
# 998        1100  2023-12-20     David   West       1629.47             39
# 999        1086  2023-08-16     Alice   East       4923.93             48
#
#     Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# ...

# %%
df.head()
# Out:
#    Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 0        1052  2023-02-03       Bob  North       5053.97             18
# 1        1093  2023-04-21       Bob   West       4384.02             17
# 2        1015  2023-09-21     David  South       4631.23             30
# 3        1072  2023-08-24       Bob  South       2167.94             39
# 4        1061  2023-03-24   Charlie   East       3750.20             13
#
#   Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# 0        Furniture     152.75      267.22     Returning      0.09
# 1        Furniture    3816.39     4209.44     Returning      0.11
# 2             Food     261.56      371.40     Returning      0.20
# 3         Clothing    4330.03     4467.75           New      0.02
# 4      Electronics     637.37      692.71           New      0.08
#
#   Payment_Method Sales_Channel Region_and_Sales_Rep
# 0           Cash        Online            North-Bob
# ...

# %%
df.columns
# Out:
# Index(['Product_ID', 'Sale_Date', 'Sales_Rep', 'Region', 'Sales_Amount',
#        'Quantity_Sold', 'Product_Category', 'Unit_Cost', 'Unit_Price',
#        'Customer_Type', 'Discount', 'Payment_Method', 'Sales_Channel',
#        'Region_and_Sales_Rep'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Product_ID            1000 non-null   int64
#  1   Sale_Date             1000 non-null   object
#  2   Sales_Rep             1000 non-null   object
#  3   Region                1000 non-null   object
#  4   Sales_Amount          1000 non-null   float64
#  5   Quantity_Sold         1000 non-null   int64
#  6   Product_Category      1000 non-null   object
#  7   Unit_Cost             1000 non-null   float64
#  8   Unit_Price            1000 non-null   float64
#  9   Customer_Type         1000 non-null   object
#  10  Discount              1000 non-null   float64
#  11  Payment_Method        1000 non-null   object
#  12  Sales_Channel         1000 non-null   object
#  13  Region_and_Sales_Rep  1000 non-null   object
# dtypes: float64(4), int64(2), object(8)
# ...

# %%
df.describe()
# Out:
#         Product_ID  Sales_Amount  Quantity_Sold    Unit_Cost   Unit_Price  \
# count  1000.000000   1000.000000    1000.000000  1000.000000  1000.000000
# mean   1050.128000   5019.265230      25.355000  2475.304550  2728.440120
# std      29.573505   2846.790126      14.159006  1417.872546  1419.399839
# min    1001.000000    100.120000       1.000000    60.280000   167.120000
# 25%    1024.000000   2550.297500      13.000000  1238.380000  1509.085000
# 50%    1051.000000   5019.300000      25.000000  2467.235000  2696.400000
# 75%    1075.000000   7507.445000      38.000000  3702.865000  3957.970000
# max    1100.000000   9989.040000      49.000000  4995.300000  5442.150000
#
#          Discount
# count  1000.00000
# mean      0.15239
# std       0.08720
# min       0.00000
# 25%       0.08000
# 50%       0.15000
# 75%       0.23000
# max       0.30000

# %%
df.columns
# Out:
# Index(['Product_ID', 'Sale_Date', 'Sales_Rep', 'Region', 'Sales_Amount',
#        'Quantity_Sold', 'Product_Category', 'Unit_Cost', 'Unit_Price',
#        'Customer_Type', 'Discount', 'Payment_Method', 'Sales_Channel',
#        'Region_and_Sales_Rep'],
#       dtype='object')

# %%
plt.figure(figsize=(9,3.5))
plt.scatter(df['Product_ID'],df['Sales_Amount'])
plt.xlabel("Product ID")
plt.ylabel("Sales_Amount")
plt.show()

# %%
def bar_plot(variable):
    var=df[variable]
    varValue=var.value_counts()
    plt.figure(figsize=(9,3))
    plt.bar(varValue.index,varValue)
    plt.xticks(varValue.index,varValue.index.values)
    plt.ylabel("frequency")
    plt.title(variable)
    plt.show()
    print("{} :\n {}".format(variable,varValue))

# %%
df.columns
# Out:
# Index(['Product_ID', 'Sale_Date', 'Sales_Rep', 'Region', 'Sales_Amount',
#        'Quantity_Sold', 'Product_Category', 'Unit_Cost', 'Unit_Price',
#        'Customer_Type', 'Discount', 'Payment_Method', 'Sales_Channel',
#        'Region_and_Sales_Rep'],
#       dtype='object')

# %%
columns_plot=[ 'Product_ID', 'Quantity_Sold', 'Region','Unit_Price','Discount']
for i in columns_plot:
    bar_plot(i)
# Out:
# Product_ID :
#  Product_ID
# 1090    20
# 1062    19
# 1092    19
# 1099    18
# 1033    18
#         ..
# 1040     5
# 1011     4
# 1041     4
# 1083     4
# 1031     3
# Name: count, Length: 100, dtype: int64
# Quantity_Sold :
#  Quantity_Sold
# 47    32
# 45    28
# 17    28
# 42    26
# 32    26
# 35    26
# 23    25
# 43    25
# 16    25
# 12    24
# 4     24
# 14    23
# 26    22
# 11    22
# 20    22
# 28    22
# 19    22
# 40    22
# 2     21
# 25    21
# 22    21
# 46    21
# 31    21
# 13    20
# 9     20
# 48    20
# 6     20
# 39    19
# 38    19
# 44    19
# 21    19
# 1     19
# 15    19
# 27    18
# 8     18
# 29    18
# 36    18
# 30    18
# 5     18
# 24    17
# 18    16
# 34    16
# 49    16
# 37    15
# 3     15
# 10    15
# 7     15
# 33    13
# 41    11
# Name: count, dtype: int64
# Region :
#  Region
# North    267
# East     263
# West     244
# South    226
# Name: count, dtype: int64
# Unit_Price :
#  Unit_Price
# 267.22     1
# 3596.64    1
# 2611.94    1
# ...

# %%
plt.hist(df['Unit_Cost'])
plt.show()

# %%
def hist_plot1(variable):
    var=df[variable]
    varValue=var.value_counts()
    plt.figure(figsize=(9,3))
    plt.bar(varValue.index,varValue)
    plt.xticks(varValue.index,varValue.index.values)
    plt.ylabel("frequency")
    plt.title(variable)
    plt.show()
    print("{} :\n {}".format(variable,varValue))

# %%
df.columns
# Out:
# Index(['Product_ID', 'Sale_Date', 'Sales_Rep', 'Region', 'Sales_Amount',
#        'Quantity_Sold', 'Product_Category', 'Unit_Cost', 'Unit_Price',
#        'Customer_Type', 'Discount', 'Payment_Method', 'Sales_Channel',
#        'Region_and_Sales_Rep'],
#       dtype='object')

# %%
columns_plot1=[ 'Payment_Method','Sales_Amount','Customer_Type']
for i in columns_plot1:
    hist_plot1(i)
# Out:
# Payment_Method :
#  Payment_Method
# Credit Card      345
# Bank Transfer    342
# Cash             313
# Name: count, dtype: int64
# Sales_Amount :
#  Sales_Amount
# 7946.69    2
# 6116.75    2
# 5053.97    1
# 2279.10    1
# 3788.08    1
#           ..
# 9673.65    1
# 611.52     1
# 5097.48    1
# 7212.69    1
# 4923.93    1
# Name: count, Length: 998, dtype: int64
# Customer_Type :
#  Customer_Type
# New          504
# Returning    496
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Product_ID', 'Sale_Date', 'Sales_Rep', 'Region', 'Sales_Amount',
#        'Quantity_Sold', 'Product_Category', 'Unit_Cost', 'Unit_Price',
#        'Customer_Type', 'Discount', 'Payment_Method', 'Sales_Channel',
#        'Region_and_Sales_Rep'],
#       dtype='object')

# %%
df[['Product_Category','Discount']].groupby(['Product_Category'],as_index=False).mean().sort_values(by="Discount",ascending=False)
# Out:
#   Product_Category  Discount
# 0         Clothing  0.160224
# 3        Furniture  0.158115
# 2             Food  0.153805
# 1      Electronics  0.136504

# %%
df[['Quantity_Sold','Discount']].groupby(['Quantity_Sold'],as_index=False).mean().sort_values(by="Discount",ascending=False)
# Out:
#     Quantity_Sold  Discount
# 39             40  0.208182
# 4               5  0.187778
# 35             36  0.180556
# 23             24  0.177647
# 24             25  0.176667
# 0               1  0.173684
# 29             30  0.171667
# 38             39  0.171053
# 10             11  0.170455
# 3               4  0.170417
# 22             23  0.168400
# 13             14  0.166522
# 46             47  0.166250
# 6               7  0.165333
# 19             20  0.165000
# 44             45  0.164286
# 25             26  0.162273
# 31             32  0.161538
# 16             17  0.157500
# 36             37  0.156000
# 40             41  0.155455
# 12             13  0.155000
# 30             31  0.153333
# 48             49  0.153125
# 1               2  0.152381
# 28             29  0.152222
# 5               6  0.152000
# 18             19  0.151818
# 14             15  0.148421
# 11             12  0.148333
# 15             16  0.147600
# 45             46  0.147143
# ...

# %%
sns.boxplot(df['Product_Category'])
# Out:
# <Axes: ylabel='Product_Category'>

# %%
sns.boxplot(df['Quantity_Sold'])
# Out:
# <Axes: ylabel='Quantity_Sold'>

# %%
df['Unit_Cost']=df['Unit_Cost'].fillna(df['Unit_Cost'].median())

# %%
df['Discount']=df['Discount'].fillna(df['Discount'].median())

# %%
df.isnull().sum()
# Out:
# Product_ID              0
# Sale_Date               0
# Sales_Rep               0
# Region                  0
# Sales_Amount            0
# Quantity_Sold           0
# Product_Category        0
# Unit_Cost               0
# Unit_Price              0
# Customer_Type           0
# Discount                0
# Payment_Method          0
# Sales_Channel           0
# Region_and_Sales_Rep    0
# dtype: int64

# %%
df['Customer_Type'].mode()
# Out:
# 0    New
# Name: Customer_Type, dtype: object

# %%
df['Customer_Type']=df['Customer_Type'].fillna(df['Customer_Type'].mode()[0])

# %%
df.isna().sum()
# Out:
# Product_ID              0
# Sale_Date               0
# Sales_Rep               0
# Region                  0
# Sales_Amount            0
# Quantity_Sold           0
# Product_Category        0
# Unit_Cost               0
# Unit_Price              0
# Customer_Type           0
# Discount                0
# Payment_Method          0
# Sales_Channel           0
# Region_and_Sales_Rep    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Product_ID', 'Sale_Date', 'Sales_Rep', 'Region', 'Sales_Amount',
#        'Quantity_Sold', 'Product_Category', 'Unit_Cost', 'Unit_Price',
#        'Customer_Type', 'Discount', 'Payment_Method', 'Sales_Channel',
#        'Region_and_Sales_Rep'],
#       dtype='object')

# %%
df.drop(labels=['Sale_Date','Product_Category'],axis=1,inplace=True)

# %%
df.head(10)
# Out:
#    Product_ID Sales_Rep Region  Sales_Amount  Quantity_Sold  Unit_Cost  \
# 0        1052       Bob  North       5053.97             18     152.75
# 1        1093       Bob   West       4384.02             17    3816.39
# 2        1015     David  South       4631.23             30     261.56
# 3        1072       Bob  South       2167.94             39    4330.03
# 4        1061   Charlie   East       3750.20             13     637.37
# 5        1021   Charlie   West       3761.15             32     900.79
# 6        1083       Bob   West        618.31             29    2408.81
# 7        1087       Eve  South       7698.92             46    3702.51
# 8        1075     David  South       4223.39             30     738.06
# 9        1075   Charlie   West       8239.58             18    2228.35
#
#    Unit_Price Customer_Type  Discount Payment_Method Sales_Channel  \
# 0      267.22     Returning      0.09           Cash        Online
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Product_ID            1000 non-null   int64
#  1   Sales_Rep             1000 non-null   object
#  2   Region                1000 non-null   object
#  3   Sales_Amount          1000 non-null   float64
#  4   Quantity_Sold         1000 non-null   int64
#  5   Unit_Cost             1000 non-null   float64
#  6   Unit_Price            1000 non-null   float64
#  7   Customer_Type         1000 non-null   object
#  8   Discount              1000 non-null   float64
#  9   Payment_Method        1000 non-null   object
#  10  Sales_Channel         1000 non-null   object
#  11  Region_and_Sales_Rep  1000 non-null   object
# dtypes: float64(4), int64(2), object(6)
# memory usage: 93.9+ KB

# %%
df['Customer_Type']=pd.get_dummies(df['Customer_Type'],drop_first=True)

# %%
df.head(10)
# Out:
#    Product_ID Sales_Rep Region  Sales_Amount  Quantity_Sold  Unit_Cost  \
# 0        1052       Bob  North       5053.97             18     152.75
# 1        1093       Bob   West       4384.02             17    3816.39
# 2        1015     David  South       4631.23             30     261.56
# 3        1072       Bob  South       2167.94             39    4330.03
# 4        1061   Charlie   East       3750.20             13     637.37
# 5        1021   Charlie   West       3761.15             32     900.79
# 6        1083       Bob   West        618.31             29    2408.81
# 7        1087       Eve  South       7698.92             46    3702.51
# 8        1075     David  South       4223.39             30     738.06
# 9        1075   Charlie   West       8239.58             18    2228.35
#
#    Unit_Price  Customer_Type  Discount Payment_Method Sales_Channel  \
# 0      267.22           True      0.09           Cash        Online
# ...

# %%
df['Sales_Rep']=pd.to_numeric(df['Sales_Rep'],errors='coerce')

# %%
df.head()
# Out:
#    Product_ID  Sales_Rep Region  Sales_Amount  Quantity_Sold  Unit_Cost  \
# 0        1052        NaN  North       5053.97             18     152.75
# 1        1093        NaN   West       4384.02             17    3816.39
# 2        1015        NaN  South       4631.23             30     261.56
# 3        1072        NaN  South       2167.94             39    4330.03
# 4        1061        NaN   East       3750.20             13     637.37
#
#    Unit_Price  Customer_Type  Discount Payment_Method Sales_Channel  \
# 0      267.22           True      0.09           Cash        Online
# 1     4209.44           True      0.11           Cash        Retail
# 2      371.40           True      0.20  Bank Transfer        Retail
# 3     4467.75          False      0.02    Credit Card        Retail
# 4      692.71          False      0.08    Credit Card        Online
#
#   Region_and_Sales_Rep
# 0            North-Bob
# 1             West-Bob
# 2          South-David
# 3            South-Bob
# ...

# %%
df.drop(labels=['Region'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Product_ID  Sales_Rep  Sales_Amount  Quantity_Sold  Unit_Cost  Unit_Price  \
# 0        1052        NaN       5053.97             18     152.75      267.22
# 1        1093        NaN       4384.02             17    3816.39     4209.44
# 2        1015        NaN       4631.23             30     261.56      371.40
# 3        1072        NaN       2167.94             39    4330.03     4467.75
# 4        1061        NaN       3750.20             13     637.37      692.71
#
#    Customer_Type  Discount Payment_Method Sales_Channel Region_and_Sales_Rep
# 0           True      0.09           Cash        Online            North-Bob
# 1           True      0.11           Cash        Retail             West-Bob
# 2           True      0.20  Bank Transfer        Retail          South-David
# 3          False      0.02    Credit Card        Retail            South-Bob
# 4          False      0.08    Credit Card        Online         East-Charlie

# %%
df.drop(labels=['Sales_Rep'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Product_ID  Sales_Amount  Quantity_Sold  Unit_Cost  Unit_Price  \
# 0        1052       5053.97             18     152.75      267.22
# 1        1093       4384.02             17    3816.39     4209.44
# 2        1015       4631.23             30     261.56      371.40
# 3        1072       2167.94             39    4330.03     4467.75
# 4        1061       3750.20             13     637.37      692.71
#
#    Customer_Type  Discount Payment_Method Sales_Channel Region_and_Sales_Rep
# 0           True      0.09           Cash        Online            North-Bob
# 1           True      0.11           Cash        Retail             West-Bob
# 2           True      0.20  Bank Transfer        Retail          South-David
# 3          False      0.02    Credit Card        Retail            South-Bob
# 4          False      0.08    Credit Card        Online         East-Charlie

# %%
df.drop(labels=['Payment_Method'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Product_ID  Sales_Amount  Quantity_Sold  Unit_Cost  Unit_Price  \
# 0        1052       5053.97             18     152.75      267.22
# 1        1093       4384.02             17    3816.39     4209.44
# 2        1015       4631.23             30     261.56      371.40
# 3        1072       2167.94             39    4330.03     4467.75
# 4        1061       3750.20             13     637.37      692.71
#
#    Customer_Type  Discount Sales_Channel Region_and_Sales_Rep
# 0           True      0.09        Online            North-Bob
# 1           True      0.11        Retail             West-Bob
# 2           True      0.20        Retail          South-David
# 3          False      0.02        Retail            South-Bob
# 4          False      0.08        Online         East-Charlie

# %%
df.drop(labels=['Region_and_Sales_Rep'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Product_ID  Sales_Amount  Quantity_Sold  Unit_Cost  Unit_Price  \
# 0        1052       5053.97             18     152.75      267.22
# 1        1093       4384.02             17    3816.39     4209.44
# 2        1015       4631.23             30     261.56      371.40
# 3        1072       2167.94             39    4330.03     4467.75
# 4        1061       3750.20             13     637.37      692.71
#
#    Customer_Type  Discount Sales_Channel
# 0           True      0.09        Online
# 1           True      0.11        Retail
# 2           True      0.20        Retail
# 3          False      0.02        Retail
# 4          False      0.08        Online

# %%
df.drop(labels=['Customer_Type'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Product_ID  Sales_Amount  Quantity_Sold  Unit_Cost  Unit_Price  Discount  \
# 0        1052       5053.97             18     152.75      267.22      0.09
# 1        1093       4384.02             17    3816.39     4209.44      0.11
# 2        1015       4631.23             30     261.56      371.40      0.20
# 3        1072       2167.94             39    4330.03     4467.75      0.02
# 4        1061       3750.20             13     637.37      692.71      0.08
#
#   Sales_Channel
# 0        Online
# 1        Retail
# 2        Retail
# 3        Retail
# 4        Online

# %%
df.drop(labels=['Sales_Channel'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Product_ID  Sales_Amount  Quantity_Sold  Unit_Cost  Unit_Price  Discount
# 0        1052       5053.97             18     152.75      267.22      0.09
# 1        1093       4384.02             17    3816.39     4209.44      0.11
# 2        1015       4631.23             30     261.56      371.40      0.20
# 3        1072       2167.94             39    4330.03     4467.75      0.02
# 4        1061       3750.20             13     637.37      692.71      0.08

# %%
sns.heatmap(df.corr(),annot=True,fmt='.2f')
plt.show()
